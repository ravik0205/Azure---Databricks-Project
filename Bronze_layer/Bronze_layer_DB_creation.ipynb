# %%
##lets create the Bronze database
spark.sql("create database if not exists bronzedb")
# Out:
# DataFrame[]

# %%
##now our database is created lets check if it exists or not ?
spark.sql("show databases").show()
# Out:
# +------------------+
# |      databaseName|
# +------------------+
# |          bronzedb|
# |           default|
# |information_schema|
# +------------------+

# %%
##our database is created but it is set to default so lets connect the one we created 
spark.sql("use bronzedb")
# Out:
# DataFrame[]

# %%
# %sql
select current_database()
---to check weaher its connected or not lets try
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>bronzedb</td></tr></tbody></table></div>
